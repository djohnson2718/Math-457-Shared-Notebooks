# %%
def D(x):
    if x <= .5:
        return 2*x
    else:
        return 2*x - 1

# %% [markdown]
# In fact, 4/7 is on a three cycle, but the computer fails to see it if you don't use an exact representation.

# %%
x = 4.0/7.0

for i in range(300):
    x = D(x)
    print x
# Out:
# 0.142857142857143
# 0.285714285714286
# 0.571428571428571
# 0.142857142857142
# 0.285714285714285
# 0.571428571428569
# 0.142857142857139
# 0.285714285714278
# 0.571428571428555
# 0.142857142857110
# 0.285714285714221
# 0.571428571428442
# 0.142857142856883
# 0.285714285713766
# 0.571428571427532
# 0.142857142855064
# 0.285714285710128
# 0.571428571420256
# 0.142857142840512
# 0.285714285681024
# 0.571428571362048
# 0.142857142724097
# 0.285714285448194
# 0.571428570896387
# 0.142857141792774
# 0.285714283585548
# 0.571428567171097
# 0.142857134342194
# 0.285714268684387
# 0.571428537368774
# 0.142857074737549
# 0.285714149475098
# 0.571428298950195
# 0.142856597900391
# 0.285713195800781
# 0.571426391601562
# 0.142852783203125
# 0.285705566406250
# 0.571411132812500
# 0.142822265625000
# 0.285644531250000
# 0.571289062500000
# 0.142578125000000
# 0.285156250000000
# 0.570312500000000
# 0.140625000000000
# 0.281250000000000
# 0.562500000000000
# 0.125000000000000
# 0.250000000000000
# ...
