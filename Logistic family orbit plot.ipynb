# %%
g = Graphics()
c=0
while c < 3.5:
    c = c +.01
    x = .5
    for i in range(50):
        x = c*x*(1-x)
        if i > 30: # give the orbit time to approach a fixed point 
            g = g + point((c,x))
        
plot(g)
# Out:
# Graphics object consisting of 6669 graphics primitives
