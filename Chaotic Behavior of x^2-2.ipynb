# %%
def f(x):
    return x^2-2

# %%
def iterate(func, start, num):
    value = start
    for i in range(num):
        value = func(value)
        print i, ": ", value

# %%
iterate(f,0,10)
# Out:
# 0 :  -2
# 1 :  2
# 2 :  2
# 3 :  2
# 4 :  2
# 5 :  2
# 6 :  2
# 7 :  2
# 8 :  2
# 9 :  2

# %%
iterate(f,.0001,300)
# Out:
# 0 :  -1.99999999000000
# 1 :  1.99999996000000
# 2 :  1.99999984000000
# 3 :  1.99999936000004
# 4 :  1.99999744000056
# 5 :  1.99998976000878
# 6 :  1.99995904013997
# 7 :  1.99983616223761
# 8 :  1.99934467579324
# 9 :  1.99737913262279
# 10 :  1.98952339943698
# 11 :  1.95820335690728
# 12 :  1.83456038700296
# 13 :  1.36561181356044
# 14 :  -0.135104374664168
# 15 :  -1.98174680794660
# 16 :  1.92732041080655
# 17 :  1.71456396591155
# 18 :  0.939729593202329
# 19 :  -1.11690829165979
# 20 :  -0.752515868021619
# 21 :  -1.43371986837567
# 22 :  0.0555526609751458
# 23 :  -1.99691390185858
# 24 :  1.98766513143606
# 25 :  1.95081267472673
# 26 :  1.80567009187446
# 27 :  1.26044448068992
# 28 :  -0.411279711098327
# 29 :  -1.83084899923888
# 30 :  1.35200805801400
# 31 :  -0.172074211065221
# 32 :  -1.97039046588628
# 33 :  1.88243858805556
# 34 :  1.54357503780061
# 35 :  0.382623897321143
# 36 :  -1.85359895319878
# 37 :  1.43582907929961
# 38 :  0.0616051449623645
# ...
